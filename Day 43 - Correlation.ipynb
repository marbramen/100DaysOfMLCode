# %% [markdown]
# #### Example of positive correlation

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

x = np.random.randint(0,50,1000)

# positive slope
y = x + 0.5*np.random.normal(0,10,1000)

mat_cov = np.corrcoef(x,y)
print(mat_cov)

plt.scatter(x,y)
plt.show()
# Out:
# [[1.         0.94281607]
#  [0.94281607 1.        ]]

# %% [markdown]
# #### Example of negative correlation

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

x = np.random.randint(0,50,1000)

# negative slope
y = 100 - x + 0.2*np.random.normal(0,10,1000)

mat_cov = np.corrcoef(x,y)
print(mat_cov)

plt.scatter(x,y)
plt.show()
# Out:
# [[ 1.         -0.99025499]
#  [-0.99025499  1.        ]]

# %% [markdown]
# #### Example of no-correlation

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

x = np.random.randint(0,50,1000)
y = x**3

mat_cov = np.corrcoef(x,y)
print(mat_cov)

plt.scatter(x,y)
plt.show()
# Out:
# [[1.         0.91266297]
#  [0.91266297 1.        ]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000) # positively correlated with 'a'
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 1000) # negatively correlated with 'a'
df['d'] = np.random.randint(0, 50, 1000) # not correlated with '

# %%
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.804905 -0.941707 -0.039619
# b  0.804905  1.000000 -0.756039 -0.036731
# c -0.941707 -0.756039  1.000000  0.032056
# d -0.039619 -0.036731  0.032056  1.000000

# %%
pd.scatter_matrix(df, figsize=(6, 6))
plt.show()
# Out:
# /home/marchelo/anaconda3/envs/ml.tools/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### References
# - Christian Cordova - Covariance and Correlation
